# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Importing Packages

# %%
# importing necessary files
import pandas as pd

# %% [markdown]
# ## Reading in Data

# %%
# reading in the historic dataframe
historic_df = pd.read_csv('../data/NABR_historic.csv') 
historic_df.head()
# Out:
#        long       lat  year TimePeriod         RCP scenario  treecanopy  \
# 0 -110.0472  37.60413  1980       Hist  historical      sc1           0
# 1 -110.0472  37.60413  1980       Hist  historical      sc1           0
# 2 -110.0472  37.60413  1980       Hist  historical      sc1           0
# 3 -110.0472  37.60413  1980       Hist  historical      sc1           0
# 4 -110.0472  37.60413  1980       Hist  historical      sc1           0
#
#    Ann_Herb  Bare  Herb  ...  PPT_Annual  T_Winter  T_Summer   T_Annual  \
# 0         0    84     5  ...       13.79  0.964835  23.15924  23.159240
# 1         0    84     5  ...        2.69  0.964835  23.15924   0.964835
# 2         0    84     5  ...       13.79  0.964835  23.15924   0.964835
# 3         0    84     5  ...        2.69  0.964835  23.15924  23.159240
# 4         0    84     5  ...         NaN       NaN       NaN        NaN
#
#    Tmax_Summer  Tmin_Winter  VWC_Winter_whole  VWC_Spring_whole  \
# 0        37.05          NaN               NaN               NaN
# 1        37.05          NaN               NaN               NaN
# 2        37.05          NaN               NaN               NaN
# 3        37.05          NaN               NaN               NaN
# 4          NaN       -12.45          0.113447          0.096831
#
#    VWC_Summer_whole  VWC_Fall_whole
# 0               NaN             NaN
# 1               NaN             NaN
# 2               NaN             NaN
# 3               NaN             NaN
# 4          0.041876        0.052298
#
# [5 rows x 29 columns]

# %%
# reading in the recent dataframe
recent_df = pd.read_csv('../data/nearterm_data_2020-2024.csv') 
recent_df.head()
# Out:
#        long       lat  year TimePeriod  RCP scenario  treecanopy  Ann_Herb  \
# 0 -110.0472  37.60413  2021         NT  4.5     sc22           0         0
# 1 -110.0472  37.60413  2021         NT  4.5     sc22           0         0
# 2 -110.0472  37.60413  2021         NT  4.5     sc23           0         0
# 3 -110.0472  37.60413  2021         NT  4.5     sc23           0         0
# 4 -110.0472  37.60413  2021         NT  4.5     sc24           0         0
#
#    Bare  Herb  ...  PPT_Annual  T_Winter  T_Summer  T_Annual  Tmax_Summer  \
# 0    84     5  ...        6.37  1.630333  24.50402  24.50402        36.89
# 1    84     5  ...         NaN       NaN       NaN       NaN          NaN
# 2    84     5  ...        3.09  1.389056  24.11043  24.11043        37.95
# 3    84     5  ...         NaN       NaN       NaN       NaN          NaN
# 4    84     5  ...        6.87 -0.334389  25.54266  10.31321        37.74
#
#    Tmin_Winter  VWC_Winter_whole  VWC_Spring_whole  VWC_Summer_whole  \
# 0          NaN               NaN               NaN               NaN
# 1       -12.77          0.114652          0.078764          0.043514
# 2          NaN               NaN               NaN               NaN
# 3       -18.96          0.130221          0.096412          0.041232
# 4          NaN               NaN               NaN               NaN
#
#    VWC_Fall_whole
# 0             NaN
# 1        0.051281
# 2             NaN
# 3        0.092241
# 4             NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Initial EDA

# %% [markdown]
# ### Data Shape

# %%
historic_df.shape
# Out:
# (13821, 29)

# %%
recent_df.shape
# Out:
# (55802, 29)

# %% [markdown]
# ### Summary Statistics for Numerical Columns

# %%
historic_df.describe()
# Out:
#                long           lat          year    treecanopy      Ann_Herb  \
# count  13821.000000  13821.000000  13821.000000  13821.000000  13821.000000
# mean    -110.005518     37.608507   1998.889299     10.062586      0.228131
# 50%        0.000000     56.000000     10.000000     10.000000     14.000000
# 75%        0.000000     67.000000     11.000000     16.000000     20.000000
# max        6.000000     94.000000     20.000000     26.000000     46.000000
#
#        ...    PPT_Annual      T_Winter      T_Summer      T_Annual  \
# count  ...  32000.000000  37882.000000  37882.000000  32000.000000
# mean   ...      7.876302      1.061328     23.896685     11.987947
# std    ...      4.170495      1.649202      1.160074      8.181101
# min    ...      0.430000     -5.392722     19.264730     -5.392722
# 25%    ...      4.790000      0.110056     23.150540      4.064556
# 50%    ...      7.300000      1.143556     23.927660     11.702030
# 75%    ...     10.360000      2.135722     24.576680     14.686260
# max    ...     33.730000      5.474725     27.745330     27.745330
#
#         Tmax_Summer   Tmin_Winter  VWC_Winter_whole  VWC_Spring_whole  \
# count  37882.000000  18273.000000      18273.000000      18273.000000
# mean      37.409251    -13.854524          0.130339          0.113198
# std        1.886281      4.273170          0.039756          0.041728
# min       31.370000    -30.270000          0.036778          0.032329
# 25%       36.280000    -16.470000          0.102253          0.079512
# 50%       37.400000    -12.900000          0.129224          0.105576
# 75%       38.290000    -10.950000          0.155793          0.144423
# max       47.170000     -6.510000          0.241642          0.219919
#
#        VWC_Summer_whole  VWC_Fall_whole
# count      18273.000000    18273.000000
# mean           0.069430        0.095702
# std            0.019916        0.031099
# min            0.029968        0.031148
# 25%            0.052745        0.073698
# 50%            0.068260        0.092410
# 75%            0.084791        0.112807
# max            0.145245        0.230940
#
# [8 rows x 27 columns]

# %% [markdown]
# Recent data ranges from 2021-2024.

# %% [markdown]
# ### Column Datatypes

# %%
historic_df.dtypes
# Out:
# long                                      float64
# lat                                       float64
# year                                        int64
# TimePeriod                                 object
# RCP                                        object
# scenario                                   object
# treecanopy                                  int64
# Ann_Herb                                    int64
# Bare                                        int64
# Herb                                        int64
# Litter                                      int64
# Shrub                                       int64
# DrySoilDays_Summer_whole                  float64
# Evap_Summer                               float64
# ExtremeShortTermDryStress_Summer_whole    float64
# FrostDays_Winter                          float64
# NonDrySWA_Summer_whole                    float64
# PPT_Winter                                float64
# PPT_Summer                                float64
# PPT_Annual                                float64
# T_Winter                                  float64
# T_Summer                                  float64
# T_Annual                                  float64
# Tmax_Summer                               float64
# Tmin_Winter                               float64
# VWC_Winter_whole                          float64
# VWC_Spring_whole                          float64
# VWC_Summer_whole                          float64
# VWC_Fall_whole                            float64
# dtype: object

# %%
recent_df.dtypes
# Out:
# long                                      float64
# lat                                       float64
# year                                        int64
# TimePeriod                                 object
# RCP                                       float64
# scenario                                   object
# treecanopy                                  int64
# Ann_Herb                                    int64
# Bare                                        int64
# Herb                                        int64
# Litter                                      int64
# Shrub                                       int64
# DrySoilDays_Summer_whole                  float64
# Evap_Summer                               float64
# ExtremeShortTermDryStress_Summer_whole    float64
# FrostDays_Winter                          float64
# NonDrySWA_Summer_whole                    float64
# PPT_Winter                                float64
# PPT_Summer                                float64
# PPT_Annual                                float64
# T_Winter                                  float64
# T_Summer                                  float64
# T_Annual                                  float64
# Tmax_Summer                               float64
# Tmin_Winter                               float64
# VWC_Winter_whole                          float64
# VWC_Spring_whole                          float64
# VWC_Summer_whole                          float64
# VWC_Fall_whole                            float64
# dtype: object
